# %%
def sum(a,b):
  print(a+b)
sum(3,4)
sum(4,5)
# Out:
# 7
# 9

# %% [markdown]
# **CLASS 6**

# %%
#kEYWORD ARGUMENTS

# %%
def key(name,marks,sub):
  print("Hi my name is ",name,"and I scored ",marks,"in",sub)
key(100,"Science","Tom")
key(marks="100 marks",name="tom",sub="kannda")
key("praveen",marks="100 marks",sub="english")
# Out:
# Hi my name is  100 and I scored  Science in Tom
# Hi my name is  tom and I scored  100 marks in kannda
# Hi my name is  praveen and I scored  100 marks in english

# %%
# default arguments
def awesome(name='praven',city="kolar",describe="gold mines"):
  print("Hey Iam",name,'from',describe,city)
awesome(city="kolar")
# Out:
# Hey Iam praven from gold mines kolar

# %%
def funct(teacher,*a):
  print("Teacher name is",teacher)
  for rollno in a:
    print("The students are",rollno)
funct("jerry",1,3,4,5,6,67)
# Out:
# Teacher name is jerry
# The students are 1
# The students are 3
# The students are 4
# The students are 5
# The students are 6
# The students are 67

# %%
def funct(teacher,*a,**kwargs):  # * is positional argument,** is 
  print("Teacher name is",teacher)
  for rollno in a:
    print("The students are",rollno)
  for subject in kwargs:
    print(subject,kwargs[subject])
funct("jerry",1,3,4,5,6,67,science=10,english=4)
# Out:
# Teacher name is jerry
# The students are 1
# The students are 3
# The students are 4
# The students are 5
# The students are 6
# The students are 67
# science 10
# english 4

# %%
#Sequence->order collection of data's

list=["A","B","C","D"]
print("A" not in list)
print("B" in list)
print(len(list))
# Out:
# False
# True
# 4

# %%
seq="hello"
print(seq.index('l',3))
# Out:
# 3

# %%
a="Engineering"
print(a.index("e",6))
# Out:
# 6

# %%
b=[1,2,3,3,4,2,5,6,7,8,2]
print(b.index(2,3,10))
# Out:
# 5

# %% [markdown]
# **Class 7**

# %%
#files -> 
'''Read mode(r)
write mode(w)
append mode(a)'''
# Out:
# 'Read mode(r)\nwrite mode(w)\nappend mode(a)'

# %%
myfile=open("file.py","r")
print(myfile.read())
# Out:
# print("hello world")

# %%
myfile.close()

# %%
myfile=open("file.py","w")
myfile.write("Developing a game 1")
# Out:
# 19

# %%
myfile=open("file.py","r")
print(myfile.read())
# Out:
# Developing a game 1

# %%
myfile=open("file.py","r")
print(myfile.read())
# Out:
# Developing a game 1

# %%
myfile=open("file1.py","r")
print(myfile.read())
# Out:
# developing a gameed by the developer

# %%
myfile=open("file1.py","w")
myfile.write("developing a game")
# Out:
# 17

# %%
myfile=open("file1.py","a+")
myfile.write("\n This is writtened by the developer")
# Out:
# 36

# %%
myfile=open("file1.py","r")
print(myfile1.read())

# %%
#context manager
with open("file.py","r") as file1:
  print(file1.read())
# Out:
# Developing a game 1

# %%
mylines=["task is been scheduled \n","Status of the task \n"," good to go"]
with open("file.py","a+") as file1:
  file1.writelines(mylines)

# %%
with open("file.py","r") as file1:
  print(file1.read())
# Out:
# Developing a game 1task is been scheduled
# Status of the task
#  good to go

# %%
# what is r+,w+,a+
#create a calculater where the values and operators to be given by the user and store the values in the file

# %%
#modules->
#built in function
import math
print(math.sin(1))
# Out:
# 0.8414709848078965

# %%
import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2022-09-21 13:39:33.020027

# %%
import datetime
x=datetime.datetime.now()
print(x.strftime("%t"))

# %%
# what is r+,w+,a+

'''The r means reading file; r+ means reading and writing the file.
The w means writing file; w+ means reading and writing the file.
The a means writing file, append mode; a+ means reading and writing file, append mode.'''

# %%
def calculator():
  operation= input('''
Please type in the math operation you would like to complete:
+ for addition
- for subtraction
* for multiplication
/ for division
''')


  num1=int(input("Enter the first number: "))
  num2=int(input("Enter the second number; "))

  if operation == '+':
    print('{} + {} = '.format(num1, num2))
    print(num1 + num2)
  elif operation == '-' :
    print('{} - {} = '.format(num1, num2))
    print(num1 - num2)
  elif operation == '*' :
    print('{} * {} = '.format(num1, num2))
    print(num1 * num2)
  elif operation == '/' :
    print('{} / {} = '.format(num1, num2))
    print(num1 / num2)
  else:
    print('You have not typed a valid operator.')
calculator()
# Out:
# Please type in the math operation you would like to complete:
# + for addition
# - for subtraction
# * for multiplication
# / for division
# *
# Enter the first number: 345
# Enter the second number; 67
# 345 * 67 =
# 23115

# %% [markdown]
# **class 8**

# %%
#Comprehension->to make a task in a simple,easier,precise way
# list Comprehension->mutable
mylist=[1,2,3,4,5,6,7,8,4]
print(mylist)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 4]

# %%
even_list=[]
for x in mylist:
  if x%2==0:
    even_list.append(x)
    print(even_list)
print(even_list)
# Out:
# [2]
# [2, 4]
# [2, 4, 6]
# [2, 4, 6, 8]
# [2, 4, 6, 8, 4]
# [2, 4, 6, 8, 4]

# %%
# list Comprehension->mutable
 
evenlist=[y for y in mylist if y%2==0]
print("The even numbers are: ",evenlist)
# Out:
# The even numbers are:  [2, 4, 6, 8, 4]

# %%
#Dic
mydic={}
for z in mylist:
  mydic[z]=z**2
print(mydic)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
#Dic comprehension
mydic_dic={x: x**2 for x in mylist}
print(mydic_dic)
# Out:
# The mydictionary is {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}

# %%
#Iterator
mylist=[1,2,3,4,5,6,7,8,4]
myiteration=iter(mylist)
print(next(myiteration))
# Out:
# 1

# %%
for i in mylist:
  myiteration=iter(mylist)
  #print(next(myiteration))
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 4

# %%
#Generator
#yield keyword
def gen(z):
  yield x+6
  yield x-6
  yield x*6
  yield x/6
